# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
from datetime import datetime

# %%
df_sales = pd.read_csv('2. ecommerce sales data 2019.csv')

# %%
df_sales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#          Order Date Purchase Address          City Postal Code
# 0    04/19/19 08:46       917 1st St        Dallas    TX 75001
# 1  04/07/2019 22:30  682 Chestnut St        Boston    MA 02215
# 2  04/12/2019 14:38    669 Spruce St   Los Angeles    CA 90001
# 3  04/12/2019 14:38    669 Spruce St   Los Angeles    CA 90001
# 4    04/30/19 09:27       333 8th St   Los Angeles    CA 90001

# %%
df_sales['City'].unique()
# Out:
# array([' Dallas', ' Boston', ' Los Angeles', ' San Francisco', ' Seattle',
#        ' Atlanta', ' New York City', ' Portland', ' Austin', 'City'],
#       dtype=object)

# %% [markdown]
# there is a space at the beginning of the word in each row. This is looks like a small problem, but it can be very annoying when we visualize in GDS, especially when filtering in Column City, if we don’t remove the space then we also have to include a space in every filter that we make in GDS.

# %%
#trim
df_sales['City'].str.strip().unique()
# Out:
# array(['Dallas', 'Boston', 'Los Angeles', 'San Francisco', 'Seattle',
#        'Atlanta', 'New York City', 'Portland', 'Austin', 'City'],
#       dtype=object)

# %% [markdown]
# One of the important columns when visualizing, especially in sales data, is the date/order_date column, we must ensure that the column is in the appropriate datetime format.

# %%
pd.to_datetime(df_sales['Order_date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1756/441501689.py in <module>
# ----> 1 pd.to_datetime(df_sales['Order_date'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Order_date'

# %% [markdown]
# ##### forcing all the fields in the column to be changed to datetime and otherwise return 'NaT'

# %%
df_sales['order_date'] = pd.to_datetime(df_sales['Order Date'],errors='coerce')

# %%
#check which row can't be converted to datetime
df_sales[df_sales['order_date'].isna()]
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 75    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 566   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 598   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 921   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2027  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2641  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3072  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3138  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3787  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3840  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address  City Postal Code order_date
# 75             Address  City    Zip Code        NaT
# 566   Purchase Address  City         NaN        NaT
# 598   Purchase Address  City         NaN        NaT
# 921   Purchase Address  City         NaN        NaT
# 2027  Purchase Address  City         NaN        NaT
# 2641  Purchase Address  City         NaN        NaT
# 3072  Purchase Address  City         NaN        NaT
# 3138  Purchase Address  City         NaN        NaT
# 3787           Address  City    Zip Code        NaT
# 3840           Address  City    Zip Code        NaT

# %%
df_sales[df_sales['order_date'].isna()].index
# Out:
# Int64Index([75, 566, 598, 921, 2027, 2641, 3072, 3138, 3787, 3840], dtype='int64')

# %%
#delete rows containing NaT
df_sales_cleaned = df_sales.drop(index=df_sales[df_sales['order_date'].isna()].index)
df_sales_cleaned[df_sales_cleaned['order_date'].isna()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, City, Postal Code, order_date]
# Index: []

# %% [markdown]
# ### Cari row yang isinga error/tidak sesuai
# ##### ketika kolom order date diubah menjadi datetime akan error (muncul exception)

# %% [markdown]
# ### Cari row yang isinga error/tidak sesuai
# ##### ketika kolom order date diubah menjadi datetime akan error (muncul exception)

# %%
df_sales_cleaned.to_csv('sales_cleaned.csv',index=False)

# %%
df_sales_cleaned.head(20)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
#